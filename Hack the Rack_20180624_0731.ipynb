# %%
"""from azureml import Workspace

ws = Workspace()
ds = ws.datasets['transactions_v2.csv']
df_transactions = ds.to_dataframe()"""

# %%
import pandas as pd
import numpy as np
import datetime

df_transactions = pd.read_csv('transactions.csv')
df_transactions.head()
# Out:
#    Store ID                     Store Type    Trans ID        Date      Time  \
# 0        27  HSR - HIGH STREET RESIDENTIAL  8151518418  2018-04-01  06:06:47
# 1        27  HSR - HIGH STREET RESIDENTIAL  8151518418  2018-04-01  06:06:48
# 2        27  HSR - HIGH STREET RESIDENTIAL  8151518418  2018-04-01  06:06:49
# 3        27  HSR - HIGH STREET RESIDENTIAL  8151518417  2018-04-01  06:07:29
# 4        27  HSR - HIGH STREET RESIDENTIAL  8151518417  2018-04-01  06:07:30
#
#    Member ID Member Grade Gender Member Birthday Prod Name (Chi)  \
# 0        NaN          NaN    NaN             NaN          東方日報每份
# 1        NaN          NaN    NaN             NaN           幸運星紙巾
# 2        NaN          NaN    NaN             NaN     VIP 報紙-$0.5
# 3        NaN          NaN    NaN             NaN          東方日報每份
# 4        NaN          NaN    NaN             NaN           幸運星紙巾
#
#            Dept                             Cat  \
# 0  Publications  Newspaper
# 1  Publications  Misc
# 2  Publications  Promotion Coupon
# 3  Publications  Newspaper
# 4  Publications  Misc
#
#                            Subcat  Sold Qty                           MOP  \
# 0  Newspaper (General)                    1  現金
# 1  Misc (General)                         1  現金
# 2  Promotion Coupon (General)             1  現金
# 3  Newspaper (General)                    1  現金
# 4  Misc (General)                         1  現金
#
#    Amount
# 0     8.0
# 1     0.0
# 2    -0.5
# 3     8.0
# 4     0.0

# %%
###################update date format###################
date_format = '%Y-%m-%d'

df_transactions['Date'] = pd.to_datetime(df_transactions['Date'],format=date_format)
 #check max txn date
max_date = df_transactions['Date'].max()
d = datetime.timedelta(1)
today = max_date + d

#df_transactions['Member ID'] = df_transactions['Member ID'].astype(str)
#df_transactions['Trans ID'] = df_transactions['Trans ID'].astype(str)
df['Subcat'] = df['Subcat'].str.strip()

###################data preview###################
print(df_transactions.head())
# Out:
#    Store ID                     Store Type    Trans ID       Date      Time  \
# 0        27  HSR - HIGH STREET RESIDENTIAL  8151518418 2018-04-01  06:06:47
# 1        27  HSR - HIGH STREET RESIDENTIAL  8151518418 2018-04-01  06:06:48
# 2        27  HSR - HIGH STREET RESIDENTIAL  8151518418 2018-04-01  06:06:49
# 3        27  HSR - HIGH STREET RESIDENTIAL  8151518417 2018-04-01  06:07:29
# 4        27  HSR - HIGH STREET RESIDENTIAL  8151518417 2018-04-01  06:07:30
#
#    Member ID Member Grade Gender Member Birthday Prod Name (Chi)  \
# 0        NaN          NaN    NaN             NaN          東方日報每份
# 1        NaN          NaN    NaN             NaN           幸運星紙巾
# 2        NaN          NaN    NaN             NaN     VIP 報紙-$0.5
# 3        NaN          NaN    NaN             NaN          東方日報每份
# 4        NaN          NaN    NaN             NaN           幸運星紙巾
#
#            Dept                             Cat  \
# 0  Publications  Newspaper
# 1  Publications  Misc
# 2  Publications  Promotion Coupon
# 3  Publications  Newspaper
# 4  Publications  Misc
#
#                            Subcat  Sold Qty                           MOP  \
# 0  Newspaper (General)                    1  現金
# 1  Misc (General)                         1  現金
# 2  Promotion Coupon (General)             1  現金
# 3  Newspaper (General)                    1  現金
# 4  Misc (General)                         1  現金
#
#    Amount
# 0     8.0
# 1     0.0
# 2    -0.5
# 3     8.0
# 4     0.0

# %%
#print(df_transactions.describe())  #-ve field: Sold Qty, Amount
#print(df_transactions.info())
#print(df_transactions.shape)  #(2759843, 16)

# %% [markdown]
# ### Data Cleaning

# %%
#drop duplicate (2622316, 16)
df_transactions.drop_duplicates(keep='first', inplace=True)

# %%
#replace member id with trans id if null
df_transactions['Member ID'] = np.where(df_transactions['Member ID'].isnull(),df_transactions['Trans ID'],df_transactions['Member ID'])

# %%
df_transactions['Member ID'] = df_transactions['Member ID'].astype('int64')
df_transactions.head()
# Out:
#    Store ID                     Store Type    Trans ID       Date      Time  \
# 0        27  HSR - HIGH STREET RESIDENTIAL  8151518418 2018-04-01  06:06:47
# 1        27  HSR - HIGH STREET RESIDENTIAL  8151518418 2018-04-01  06:06:48
# 2        27  HSR - HIGH STREET RESIDENTIAL  8151518418 2018-04-01  06:06:49
# 3        27  HSR - HIGH STREET RESIDENTIAL  8151518417 2018-04-01  06:07:29
# 4        27  HSR - HIGH STREET RESIDENTIAL  8151518417 2018-04-01  06:07:30
#
#     Member ID Member Grade Gender Member Birthday Prod Name (Chi)  \
# 0  8151518418          NaN    NaN             NaN          東方日報每份
# 1  8151518418          NaN    NaN             NaN           幸運星紙巾
# 2  8151518418          NaN    NaN             NaN     VIP 報紙-$0.5
# 3  8151518417          NaN    NaN             NaN          東方日報每份
# 4  8151518417          NaN    NaN             NaN           幸運星紙巾
#
#            Dept                             Cat  \
# 0  Publications  Newspaper
# 1  Publications  Misc
# 2  Publications  Promotion Coupon
# 3  Publications  Newspaper
# 4  Publications  Misc
#
#                            Subcat  Sold Qty                           MOP  \
# 0  Newspaper (General)                    1  現金
# 1  Misc (General)                         1  現金
# 2  Promotion Coupon (General)             1  現金
# 3  Newspaper (General)                    1  現金
# 4  Misc (General)                         1  現金
#
#    Amount
# 0     8.0
# 1     0.0
# 2    -0.5
# 3     8.0
# 4     0.0

# %%
#select +ve price only
df_pos = df_transactions[(df_transactions['Sold Qty'] > 0) & (df_transactions['Amount'] > 0)]
print(df_pos.shape) #(2077101, 16)
print(df_pos.isnull().sum())  #783 is null for Subcat
# Out:
# (2077101, 16)
# Store ID                 0
# Store Type               0
# Trans ID                 0
# Date                     0
# Time                     0
# Member ID                0
# Member Grade       1765936
# Gender             1777619
# Member Birthday    1806638
# Prod Name (Chi)          0
# Dept                     0
# Cat                      0
# Subcat                 783
# Sold Qty                 0
# MOP                      0
# Amount                   0
# dtype: int64

# %%
#df_pos.loc[(df_pos['Prod Name (Chi)'] == 'çéå°æ¥­é¦å£ç 8ç²è£')&(df_pos['Subcat'].isnull()), 'Subcat']= 'Gum'

df_pos.loc[(df_pos['Prod Name (Chi)'] == '益達專業香口珠8粒裝')&(df_pos['Subcat'].isnull()), 'Subcat']= 'Gum'
# Out:
# C:\Users\Tse\Anaconda3\lib\site-packages\pandas\core\indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
df_pos.head()
# Out:
#     Store ID                     Store Type    Trans ID       Date      Time  \
# 0         27  HSR - HIGH STREET RESIDENTIAL  8151518418 2018-04-01  06:06:47
# 3         27  HSR - HIGH STREET RESIDENTIAL  8151518417 2018-04-01  06:07:29
# 6         27  HSR - HIGH STREET RESIDENTIAL  8151518416 2018-04-01  06:07:48
# 7         27  HSR - HIGH STREET RESIDENTIAL  8151518416 2018-04-01  06:07:55
# 10        27  HSR - HIGH STREET RESIDENTIAL  8151518415 2018-04-01  06:09:38
#
#      Member ID Member Grade Gender Member Birthday Prod Name (Chi)  \
# 0   8151518418          NaN    NaN             NaN          東方日報每份
# 3   8151518417          NaN    NaN             NaN          東方日報每份
# 6   8151518416          NaN    NaN             NaN          東方日報每份
# 7   8151518416          NaN    NaN             NaN          東方日報每份
# 10  8151518415          NaN    NaN             NaN          東方日報每份
#
#             Dept                             Cat  \
# 0   Publications  Newspaper
# 3   Publications  Newspaper
# 6   Publications  Newspaper
# 7   Publications  Newspaper
# 10  Publications  Newspaper
#
#                             Subcat  Sold Qty                             MOP  \
# 0   Newspaper (General)                    1    現金
# 3   Newspaper (General)                    1    現金
# 6   Newspaper (General)                    1  Octopus
# 7   Newspaper (General)                    1  Octopus
# 10  Newspaper (General)                    1    現金
#
#     Amount
# 0      8.0
# 3      8.0
# 6      8.0
# 7      8.0
# 10     8.0

# %%
df_pos.to_csv('df_transactions_clean.csv')

# %% [markdown]
# ### Data Manipulation

# %%
#############################Unique column#############################
#Check unique value for each column
def unique_counts(df):
    for i in df.columns:
        count = df[i].nunique()
        print(i, ": ", count)
unique_counts(df_transactions)

unique_counts(df_pos)
# Out:
# Store ID :  30
# Store Type :  7
# Trans ID :  1540100
# Date :  31
# Time :  85744
# Member ID :  1436109
# Member Grade :  3
# Gender :  2
# Member Birthday :  616
# Prod Name (Chi) :  4716
# Dept :  20
# Cat :  123
# Subcat :  314
# Sold Qty :  95
# MOP :  8
# Amount :  5818
# Store ID :  30
# Store Type :  7
# Trans ID :  1529210
# Date :  31
# Time :  85617
# Member ID :  1424995
# Member Grade :  3
# Gender :  2
# Member Birthday :  616
# Prod Name (Chi) :  3440
# Dept :  19
# Cat :  113
# Subcat :  295
# Sold Qty :  71
# MOP :  8
# Amount :  5337

# %%
#############################RFM#############################
#Create RFM table
def rfm(df, cust_id, invoice_no, invoice_date, unit_price):
    
    rfmTable = df.groupby(cust_id).agg({invoice_date: lambda x: (today - x.max()).days, \
                                        invoice_no: 'nunique', \
                                        'Amount': lambda x: x.sum()})
    rfmTable[invoice_date] = rfmTable[invoice_date].astype(int)   
    rfmTable.rename(columns={invoice_date: 'recency', 
                             invoice_no: 'frequency', 
                             'Amount': 'monetary_value'}, inplace=True)
    return rfmTable

def rfm_seg():
     
    quantiles = df_rfm.quantile(q=[0.25,0.5,0.75])
    quantiles = quantiles.to_dict()

    #The lowest recency, highest frequency and monetary amounts are the best customers
    def RScore(x,p,d):
        if x <= d[p][0.25]:
            return 1
        elif x <= d[p][0.50]:
            return 2
        elif x <= d[p][0.75]: 
            return 3
        else:
            return 4
    
    def FMScore(x,p,d):
        if x <= d[p][0.25]:
            return 4
        elif x <= d[p][0.50]:
            return 3
        elif x <= d[p][0.75]: 
            return 2
        else:
            return 1

    segmented_rfm = df_rfm.copy()
    segmented_rfm['r_quartile'] = segmented_rfm['recency'].apply(RScore, args=('recency',quantiles,))
    segmented_rfm['f_quartile'] = segmented_rfm['frequency'].apply(FMScore, args=('frequency',quantiles,))
    segmented_rfm['m_quartile'] = segmented_rfm['monetary_value'].apply(FMScore, args=('monetary_value',quantiles,))
    #Add a new column to combine RFM score: 111 is the highest score
    segmented_rfm['RFMScore'] = segmented_rfm.r_quartile.map(str) + segmented_rfm.f_quartile.map(str) + segmented_rfm.m_quartile.map(str)
    #return segmented_rfm[segmented_rfm['RFMScore'] == rfm_score].index.get_values()
    return segmented_rfm

#create rfm_seg index list
def rfm_seg_index(r, f, m):
    
    df = rfm_seg()
    
    df = df[(df['r_quartile'] == r)&(df['f_quartile'] == f)&(df['m_quartile'] == m)]
    
    return df.index.get_values().tolist()

#combine rfm_seg index list
def combine_rfm_seg_index(inc_list):
    
    i_list = []
    
    for i in range(0, len(inc_list)):
        i_list += inc_list[i]
        
    return i_list

# %%
#############################pre-processing#############################
def cust_lv(df, cust_id, stock_code, quantity, unit_price, invoice_no):

    df_cust_txn = df.groupby([cust_id]).agg({
                                                invoice_no: {'total_transactions':'nunique'}, \
                                                stock_code: {'total_products':'count','total_unique_products':'nunique'}, \
                                                'Amount': {'total_sales': 'sum','avg_product_value': 'mean'}, \
                                                quantity: {'total_quantity': 'sum'}})
    df_cust_txn.columns = df_cust_txn.columns.droplevel()
        
    return df_cust_txn


def cust_pdt(df, cust_id, stock_code, quantity, unit_price, invoice_no):
        
    df_cust_txn = df.groupby([cust_id,stock_code]).agg({
                                                invoice_no: {'total_transactions':'nunique'}, \
                                                quantity: {'total_quantity': 'sum'}})
    df_cust_txn.columns = df_cust_txn.columns.droplevel()
        
    return df_cust_txn.reset_index(stock_code)

# %%
###################################################
#update col name for RFM table
df_rfm = rfm(df_pos, 'Member ID', 'Trans ID', 'Date','Amount')
df_rfm.head()
# Out:
#            recency  frequency  monetary_value
# Member ID
# 92              11          2            73.9
# 93               4          3            49.1
# 185              2         56          1395.5
# 273              7          3            30.9
# 274             13         13           211.2

# %%
#create rfm_seg
df_rfm_seg = rfm_seg()
#rfm_list = [rfm_seg_index(2, 1, 1), rfm_seg_index(3, 1, 1), rfm_seg_index(4, 1, 1)]
rfm_list = [rfm_seg_index(2, 1, 1)]

rfm_col_list = combine_rfm_seg_index(rfm_list)

# %%
rfm_col_list = combine_rfm_seg_index(rfm_list)
for i in range(0,len(rfm_list)):
    print (len(rfm_list[i]))
# Out:
# 1719

# %%
#create table in cust lv
df_cust_lv = cust_lv(df_pos, 'Member ID', 'Subcat', 'Sold Qty', 'Amount', 'Trans ID')
df_cust_lv.head()
# Out:
# C:\Users\Tse\Anaconda3\lib\site-packages\pandas\core\groupby.py:4291: FutureWarning: using a dict with renaming is deprecated and will be removed in a future version
#   return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#            total_transactions  total_products  total_unique_products  \
# Member ID
# 92                          2               6                      4
# 93                          3               6                      2
# 185                        56             112                     37
# 273                         3               3                      2
# 274                        13              18                      8
#
#            total_sales  avg_product_value  total_quantity
# Member ID
# 92                73.9          12.316667               6
# 93                49.1           8.183333               6
# 185             1395.5          12.459821             120
# 273               30.9          10.300000               3
# 274              211.2          11.733333              18

# %%
df_cust_by_pdt = cust_pdt(df_pos, 'Member ID', 'Subcat', 'Sold Qty', 'Amount', 'Trans ID')
df_cust_by_pdt.head()
# Out:
# C:\Users\Tse\Anaconda3\lib\site-packages\pandas\core\groupby.py:4291: FutureWarning: using a dict with renaming is deprecated and will be removed in a future version
#   return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#                                    Subcat  total_transactions  total_quantity
# Member ID
# 92         236ML                                            1               1
# 92         ASAHI                                            1               1
# 92         INTERNATIONAL SOURCING JAPAN                     1               2
# 92         SM<=500ML                                        1               2
# 93         Bottle                                           1               2

# %%
df_cust_basic = pd.concat([df_cust_lv[['total_products','total_quantity']], df_rfm],axis=1)
df_cust_basic.describe()
# Out:
#        total_products  total_quantity       recency     frequency  \
# count    1.424995e+06    1.424995e+06  1.424995e+06  1.424995e+06
# mean     1.457620e+00    1.526747e+00  1.591253e+01  1.086727e+00
# std      1.969584e+00    2.628856e+00  8.617362e+00  9.713118e-01
# min      1.000000e+00    1.000000e+00  1.000000e+00  1.000000e+00
# 25%      1.000000e+00    1.000000e+00  8.000000e+00  1.000000e+00
# 50%      1.000000e+00    1.000000e+00  1.600000e+01  1.000000e+00
# 75%      1.000000e+00    1.000000e+00  2.300000e+01  1.000000e+00
# max      1.630000e+02    5.000000e+02  3.100000e+01  1.200000e+02
#
#        monetary_value
# count    1.424995e+06
# mean     8.975904e+01
# std      2.232271e+02
# min      4.000000e-01
# 25%      9.500000e+00
# 50%      2.750000e+01
# 75%      1.000000e+02
# max      1.000000e+04

# %% [markdown]
# ### Dimensionality Reduction

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from scipy.spatial.distance import cdist, pdist
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.decomposition import SparsePCA

# %%
#############update value#####################
top_n = 20
random_state = 123
pca_var = 0.8

# %%
def d_reduction(df, cust_id, stock_code, top_n, seg):
    
    df_seg = df[df[cust_id].isin(seg)]
    df_item = pd.get_dummies(df_seg[[cust_id, stock_code]], columns = [stock_code])
    # Create item_data by aggregating at customer level
    df_item_by_cust = df_item.groupby(cust_id).sum()
    # Get list of StockCodes for the n most popular items
    top_n_items = df_item_by_cust.sum().sort_values().tail(top_n).index.tolist()
    df_item_by_cust = df_item_by_cust[top_n_items]
    
    return (df_item_by_cust, top_n_items)

df_cust_txn_seg, top_n_items = d_reduction(df_transactions, 'Member ID', 'Subcat', top_n, rfm_col_list)

# %% [markdown]
# ### PCA

# %%
######################PCA###########################
pca_test = PCA(pca_var).fit(df_cust_txn_seg)
pca_n = pca_test.n_components_
print(pca_n)
# Out:
# 11

# %%
#pca plot
pca = PCA().fit(df_cust_txn_seg)
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('No of componrnts')
plt.ylabel('cumulative explained variance')
plt.show()

# %%
print(pca.explained_variance_ )
plt.plot(range(len(pca.explained_variance_)),pca.explained_variance_,'bx-')
plt.xlabel('Principal Components')
plt.ylabel('Explained Variance')
plt.title('Explained Variance of Each Principal Component')
plt.show()
# Out:
# [4.26351765 3.10676237 2.99867604 2.61641404 1.95975392 1.89274381
#  1.47557633 1.2769514  1.22544356 1.10514543 0.99984549 0.93917346
#  0.84169828 0.7740415  0.65790022 0.5975625  0.49462029 0.31257119
#  0.22873006 0.16877476]

# %%
pca = PCA(n_components=pca_n)
pca.fit_transform(df_cust_txn_seg)
# PCA_5                                0.007617
# PCA_6                               -0.028920
# PCA_7                               -0.038238
# PCA_8                               -0.001415
# PCA_9                                0.012097
# PCA_10                               0.016912
#
#         Subcat_Appolo                          \
# PCA_0                                0.184858
# PCA_1                                0.040369
# PCA_2                               -0.070057
# PCA_3                               -0.097356
# PCA_4                               -0.395183
# PCA_5                               -0.234647
# PCA_6                                0.584402
# PCA_7                                0.200382
# PCA_8                               -0.500757
# PCA_9                                0.112394
# PCA_10                               0.059595
#
#         Subcat_236ML                           \
# PCA_0                                0.307130
# PCA_1                                0.224600
# PCA_2                               -0.147491
# PCA_3                               -0.472692
# PCA_4                                0.719721
# PCA_5                               -0.020739
# PCA_6                                0.244756
# PCA_7                               -0.055665
# PCA_8                               -0.016923
# PCA_9                                0.006778
# PCA_10                               0.022812
#
#         Subcat_Tetra Pack                      \
# PCA_0                                0.363762
# PCA_1                                0.096276
# PCA_2                               -0.074023
# PCA_3                               -0.548469
# PCA_4                               -0.476504
# PCA_5                                0.494251
# PCA_6                               -0.208449
# PCA_7                               -0.049009
# PCA_8                                0.172155
# PCA_9                               -0.004241
# PCA_10                               0.015893
#
#         Subcat_946ML                           \
# PCA_0                               -0.044034
# PCA_1                                0.430170
# PCA_2                               -0.509931
# PCA_3                                0.478955
# PCA_4                                0.013210
# PCA_5                                0.496976
# PCA_6                                0.195599
# PCA_7                                0.029981
# PCA_8                                0.017269
# PCA_9                                0.049807
# PCA_10                              -0.018162
#
#         Subcat_LOYALTYPROG COU(General)        \
# PCA_0                                0.450695
# PCA_1                                0.399755
# PCA_2                               -0.211453
# PCA_3                                0.204978
# PCA_4                               -0.113226
# PCA_5                               -0.525601
# PCA_6                               -0.448877
# PCA_7                               -0.179327
# PCA_8                               -0.048666
# PCA_9                                0.013581
# PCA_10                              -0.004856
#
#         Subcat_Bottle
# PCA_0                                0.697339
# PCA_1                               -0.379960
# PCA_2                                0.298521
# PCA_3                                0.425594
# PCA_4                                0.141020
# PCA_5                                0.234365
# PCA_6                                0.091728
# PCA_7                                0.020498
# PCA_8                                0.028073
# PCA_9                                0.015619
# PCA_10                              -0.024848

# %% [markdown]
# ### K-mean

# %%
#check for 0 value
df_cust_basic.describe()
# Out:
#        total_products  total_quantity       recency     frequency  \
# count    1.424995e+06    1.424995e+06  1.424995e+06  1.424995e+06
# mean     1.457620e+00    1.526747e+00  1.591253e+01  1.086727e+00
# std      1.969584e+00    2.628856e+00  8.617362e+00  9.713118e-01
# min      1.000000e+00    1.000000e+00  1.000000e+00  1.000000e+00
# 25%      1.000000e+00    1.000000e+00  8.000000e+00  1.000000e+00
# 50%      1.000000e+00    1.000000e+00  1.600000e+01  1.000000e+00
# 75%      1.000000e+00    1.000000e+00  2.300000e+01  1.000000e+00
# max      1.630000e+02    5.000000e+02  3.100000e+01  1.200000e+02
#
#        monetary_value
# count    1.424995e+06
# mean     8.975904e+01
# std      2.232271e+02
# min      4.000000e-01
# 25%      9.500000e+00
# 50%      2.750000e+01
# 75%      1.000000e+02
# max      1.000000e+04

# %%
######################normalization######################
#take log to columns with zero
df_cust_basic['total_products'] = np.log(df_cust_basic['total_products']+1)
df_cust_basic['total_quantity'] = np.log(df_cust_basic['total_quantity']+1)
df_cust_basic['monetary_value'] = np.log(df_cust_basic['monetary_value']+1)
df_cust_basic['frequency'] = np.log(df_cust_basic['frequency']+1)
df_cust_basic['recency'] = np.log(df_cust_basic['recency']+1)

#feature scaling
df_cust_basic_std = pd.DataFrame(StandardScaler().fit_transform(df_cust_basic), columns=df_cust_basic.columns)
df_cust_basic_std.describe()

X = pd.merge(df_cust_txn_seg, df_cust_basic, left_index=True, right_index=True, how = 'left')

# %%
# k means determine k
distortions = []
K = range(1,10)
for k in K:
    kmeanModel = KMeans(n_clusters=k,random_state=random_state).fit(X)
    kmeanModel.fit(X)
    distortions.append(sum(np.min(cdist(X, kmeanModel.cluster_centers_, 'euclidean'), axis=1)) / X.shape[0])
    
# Plot the elbow
plt.plot(K, distortions, 'bx-')
plt.xlabel('k')
plt.ylabel('WSS')
plt.title('The Elbow Method showing optimal k')
plt.show()

# %%
#########update n_clusters#########
# k means prediction
kmeanModel = KMeans(n_clusters=5,random_state=random_state).fit(X)
kmeanModel.fit(X)
y = kmeanModel.predict(X)

# %%
#df_cluster = pd.DataFrame(y, index = X.index)
#df_cluster.columns = ['cluster']

df_final = pd.concat([X, pd.DataFrame(y, index = X.index)])
df_final.head()
# Out:
# C:\Users\Tse\Anaconda3\lib\site-packages\pandas\core\indexes\api.py:87: RuntimeWarning: '<' not supported between instances of 'str' and 'int', sort order is undefined for incomparable objects
#   result = result.union(other)
#            Subcat_Coupon (General)                \
# Member ID
# 274                                          0.0
# 54151                                        0.0
# 63968                                        0.0
# 72178                                        0.0
# 81685                                        0.0
#
#            Subcat_Bite Size                       \
# Member ID
# 274                                          0.0
# 54151                                        0.0
# 63968                                        0.0
# 72178                                        3.0
# 81685                                        2.0
#
#            Subcat_HOT TITLES                      \
# Member ID
# 274                                          0.0
# 54151                                        0.0
# 63968                                        0.0
# 72178                                        0.0
# 81685                                        0.0
#
#            Subcat_Non-Menthol Lights KS           \
# Member ID
# 274                                          0.0
# 54151                                        0.0
# 63968                                        0.0
# 72178                                        0.0
# 81685                                        0.0
#
#            Subcat_Cakes                           \
# Member ID
# 274                                          0.0
# 54151                                        0.0
# 63968                                        0.0
# 72178                                        0.0
# 81685                                        0.0
#
#            Subcat_Non-Menthol Full Flavor KS      \
# Member ID
# 274                                          0.0
# 54151                                        0.0
# 63968                                        0.0
# 72178                                        0.0
# 81685                                        0.0
#
#            Subcat_FBA Bun(General)                \
# Member ID
# 274                                          0.0
# 54151                                        0.0
# 63968                                        0.0
# 72178                                        0.0
# 81685                                        1.0
#
#            Subcat_Can                             \
# Member ID
# 274                                          5.0
# 54151                                        0.0
# 63968                                        0.0
# 72178                                        0.0
# 81685                                        0.0
#
#            Subcat_Newspaper (General)             \
# Member ID
# 274                                          0.0
# 54151                                        0.0
# 63968                                        0.0
# 72178                                        1.0
# 81685                                        0.0
#
#            Subcat_Potato                         ...  \
# Member ID                                        ...
# 274                                          0.0 ...
# 54151                                        0.0 ...
# 63968                                        0.0 ...
# 72178                                        2.0 ...
# 81685                                        0.0 ...
#
#            Subcat_946ML                           \
# Member ID
# 274                                          0.0
# 54151                                        0.0
# 63968                                        0.0
# 72178                                        0.0
# 81685                                        0.0
#
#            Subcat_LOYALTYPROG COU(General)        \
# Member ID
# 274                                          6.0
# 54151                                        3.0
# 63968                                        3.0
# 72178                                       11.0
# 81685                                        0.0
#
#            Subcat_Bottle                          total_products  \
# Member ID
# 274                                          0.0        2.944439
# 54151                                        2.0        1.945910
# 63968                                        3.0        1.609438
# 72178                                        6.0        3.178054
# 81685                                        2.0        2.484907
#
#            total_quantity   recency  frequency  monetary_value  clusters   0
# Member ID
# 274              2.944439  2.639057   2.639057        5.357529       4.0 NaN
# 54151            1.945910  2.302585   1.386294        4.757033       4.0 NaN
# 63968            1.609438  2.397895   1.386294        4.840242       4.0 NaN
# 72178            3.367296  2.302585   2.197225        5.809043       4.0 NaN
# 81685            2.484907  2.639057   1.945910        5.642262       2.0 NaN
#
# [5 rows x 27 columns]

# %%
df_cluster = pd.DataFrame(y, index = X.index)
df_cluster.columns= ['cluster']
df_cluster.head()
# Out:
#            cluster
# Member ID
# 274              3
# 54151            3
# 63968            3
# 72178            3
# 81685            1

# %%
df_final = pd.merge(X, df_cluster, left_index = True, right_index = True)
df_final.head()
# Out:
#            Subcat_Coupon (General)                \
# Member ID
# 274                                            0
# 54151                                          0
# 63968                                          0
# 72178                                          0
# 81685                                          0
#
#            Subcat_Bite Size                       \
# Member ID
# 274                                            0
# 54151                                          0
# 63968                                          0
# 72178                                          3
# 81685                                          2
#
#            Subcat_HOT TITLES                      \
# Member ID
# 274                                            0
# 54151                                          0
# 63968                                          0
# 72178                                          0
# 81685                                          0
#
#            Subcat_Non-Menthol Lights KS           \
# Member ID
# 274                                            0
# 54151                                          0
# 63968                                          0
# 72178                                          0
# 81685                                          0
#
#            Subcat_Cakes                           \
# Member ID
# 274                                            0
# 54151                                          0
# 63968                                          0
# 72178                                          0
# 81685                                          0
#
#            Subcat_Non-Menthol Full Flavor KS      \
# Member ID
# 274                                            0
# 54151                                          0
# 63968                                          0
# 72178                                          0
# 81685                                          0
#
#            Subcat_FBA Bun(General)                \
# Member ID
# 274                                            0
# 54151                                          0
# 63968                                          0
# 72178                                          0
# 81685                                          1
#
#            Subcat_Can                             \
# Member ID
# 274                                            5
# 54151                                          0
# 63968                                          0
# 72178                                          0
# 81685                                          0
#
#            Subcat_Newspaper (General)             \
# Member ID
# 274                                            0
# 54151                                          0
# 63968                                          0
# 72178                                          1
# 81685                                          0
#
#            Subcat_Potato                           ...     \
# Member ID                                          ...
# 274                                            0   ...
# 54151                                          0   ...
# 63968                                          0   ...
# 72178                                          2   ...
# 81685                                          0   ...
#
#            Subcat_946ML                           \
# Member ID
# 274                                            0
# 54151                                          0
# 63968                                          0
# 72178                                          0
# 81685                                          0
#
#            Subcat_LOYALTYPROG COU(General)        \
# Member ID
# 274                                            6
# 54151                                          3
# 63968                                          3
# 72178                                         11
# 81685                                          0
#
#            Subcat_Bottle                          total_products  \
# Member ID
# 274                                            0        2.944439
# 54151                                          2        1.945910
# 63968                                          3        1.609438
# 72178                                          6        3.178054
# 81685                                          2        2.484907
#
#            total_quantity   recency  frequency  monetary_value  clusters  \
# Member ID
# 274              2.944439  2.639057   2.639057        5.357529         4
# 54151            1.945910  2.302585   1.386294        4.757033         4
# 63968            1.609438  2.397895   1.386294        4.840242         4
# 72178            3.367296  2.302585   2.197225        5.809043         4
# 81685            2.484907  2.639057   1.945910        5.642262         2
#
#            cluster
# Member ID
# 274              3
# 54151            3
# 63968            3
# 72178            3
# 81685            1
#
# [5 rows x 27 columns]

# %%
print('total sum', '\n')
print(df_final.iloc[:].sum(), '\n', '\n')

for i in df_final['cluster'].unique():
    print('custer' + str(i) + 'sum', '\n')
    print(df_final[df_final['cluster'] == i].iloc[:].sum(), '\n', '\n')
# Out:
# total sum
#
# Subcat_Coupon (General)                   237.000000
# Subcat_Bite Size                          238.000000
# Subcat_HOT TITLES                         265.000000
# Subcat_Non-Menthol Lights KS              265.000000
# Subcat_Cakes                              266.000000
# Subcat_Non-Menthol Full Flavor KS         283.000000
# Subcat_FBA Bun(General)                   338.000000
# Subcat_Can                                353.000000
# Subcat_Newspaper (General)                360.000000
# Subcat_Potato                             386.000000
# Subcat_Menthol Lights KS                  462.000000
# Subcat_Nestle                             481.000000
# Subcat_Menthol Ultra Lights KS            546.000000
# Subcat_Misc (General)                     569.000000
# Subcat_Appolo                             645.000000
# Subcat_236ML                              661.000000
# Subcat_Tetra Pack                         745.000000
# Subcat_946ML                              834.000000
# Subcat_LOYALTYPROG COU(General)          1291.000000
# Subcat_Bottle                            1600.000000
# total_products                           3636.270583
# total_quantity                           3751.237566
# recency                                  4321.489428
# frequency                                2825.478421
# monetary_value                           8742.040945
# clusters                                 4329.000000
# cluster                                  2979.000000
# dtype: float64
#
#
# custer3sum
#
# Subcat_Coupon (General)                    76.000000
# Subcat_Bite Size                          103.000000
# Subcat_HOT TITLES                          91.000000
# Subcat_Non-Menthol Lights KS               10.000000
# Subcat_Cakes                               63.000000
# Subcat_Non-Menthol Full Flavor KS          11.000000
# Subcat_FBA Bun(General)                    59.000000
# Subcat_Can                                 52.000000
# Subcat_Newspaper (General)                 32.000000
# Subcat_Potato                             241.000000
# Subcat_Menthol Lights KS                    4.000000
# Subcat_Nestle                             295.000000
# Subcat_Menthol Ultra Lights KS             17.000000
# Subcat_Misc (General)                     130.000000
# Subcat_Appolo                             513.000000
# Subcat_236ML                              338.000000
# Subcat_Tetra Pack                         482.000000
# Subcat_946ML                               63.000000
# Subcat_LOYALTYPROG COU(General)           748.000000
# Subcat_Bottle                             291.000000
# total_products                            785.658636
# total_quantity                            818.559637
# recency                                   754.608997
# frequency                                 546.197148
# monetary_value                           1568.976488
# clusters                                 1510.000000
# cluster                                   912.000000
# dtype: float64
#
#
# custer1sum
#
# Subcat_Coupon (General)                    43.000000
# Subcat_Bite Size                           75.000000
# Subcat_HOT TITLES                         144.000000
# Subcat_Non-Menthol Lights KS              230.000000
# Subcat_Cakes                              128.000000
# Subcat_Non-Menthol Full Flavor KS         261.000000
# Subcat_FBA Bun(General)                   230.000000
# Subcat_Can                                190.000000
# Subcat_Newspaper (General)                 82.000000
# Subcat_Potato                              70.000000
# Subcat_Menthol Lights KS                  431.000000
# Subcat_Nestle                             122.000000
# Subcat_Menthol Ultra Lights KS            501.000000
# Subcat_Misc (General)                     256.000000
# Subcat_Appolo                              38.000000
# Subcat_236ML                              216.000000
# Subcat_Tetra Pack                         139.000000
# Subcat_946ML                               64.000000
# Subcat_LOYALTYPROG COU(General)           230.000000
# Subcat_Bottle                             353.000000
# total_products                           2060.315087
# total_quantity                           2126.318543
# recency                                  2751.354834
# frequency                                1660.833290
# monetary_value                           5498.569777
# clusters                                 2134.000000
# cluster                                  1085.000000
# dtype: float64
#
#
# custer2sum
#
# Subcat_Coupon (General)                  104.000000
# Subcat_Bite Size                           7.000000
# Subcat_HOT TITLES                          7.000000
# Subcat_Non-Menthol Lights KS               0.000000
# Subcat_Cakes                              31.000000
# Subcat_Non-Menthol Full Flavor KS          0.000000
# Subcat_FBA Bun(General)                    7.000000
# Subcat_Can                                 2.000000
# Subcat_Newspaper (General)                17.000000
# Subcat_Potato                              8.000000
# Subcat_Menthol Lights KS                   2.000000
# Subcat_Nestle                             20.000000
# Subcat_Menthol Ultra Lights KS             1.000000
# Subcat_Misc (General)                     22.000000
# Subcat_Appolo                             17.000000
# Subcat_236ML                              36.000000
# Subcat_Tetra Pack                          7.000000
# Subcat_946ML                             693.000000
# Subcat_LOYALTYPROG COU(General)          122.000000
# Subcat_Bottle                             21.000000
# total_products                           283.832736
# total_quantity                           287.936529
# recency                                  338.579794
# frequency                                244.239630
# monetary_value                           686.307727
# clusters                                 408.000000
# cluster                                  274.000000
# dtype: float64
#
#
# custer0sum
#
# Subcat_Coupon (General)                    5.000000
# Subcat_Bite Size                           0.000000
# Subcat_HOT TITLES                          8.000000
# Subcat_Non-Menthol Lights KS               9.000000
# Subcat_Cakes                               0.000000
# Subcat_Non-Menthol Full Flavor KS          0.000000
# Subcat_FBA Bun(General)                    5.000000
# Subcat_Can                                 0.000000
# Subcat_Newspaper (General)               209.000000
# Subcat_Potato                              0.000000
# Subcat_Menthol Lights KS                   0.000000
# Subcat_Nestle                              3.000000
# Subcat_Menthol Ultra Lights KS             0.000000
# Subcat_Misc (General)                    127.000000
# Subcat_Appolo                              0.000000
# Subcat_236ML                               3.000000
# Subcat_Tetra Pack                          0.000000
# Subcat_946ML                               2.000000
# Subcat_LOYALTYPROG COU(General)           13.000000
# Subcat_Bottle                              0.000000
# total_products                            44.620594
# total_quantity                            44.620594
# recency                                   39.305566
# frequency                                 39.328039
# monetary_value                            81.919585
# clusters                                  96.000000
# cluster                                    0.000000
# dtype: float64
#
#
# custer4sum
#
# Subcat_Coupon (General)                    9.000000
# Subcat_Bite Size                          53.000000
# Subcat_HOT TITLES                         15.000000
# Subcat_Non-Menthol Lights KS              16.000000
# Subcat_Cakes                              44.000000
# Subcat_Non-Menthol Full Flavor KS         11.000000
# Subcat_FBA Bun(General)                   37.000000
# Subcat_Can                               109.000000
# Subcat_Newspaper (General)                20.000000
# Subcat_Potato                             67.000000
# Subcat_Menthol Lights KS                  25.000000
# Subcat_Nestle                             41.000000
# Subcat_Menthol Ultra Lights KS            27.000000
# Subcat_Misc (General)                     34.000000
# Subcat_Appolo                             77.000000
# Subcat_236ML                              68.000000
# Subcat_Tetra Pack                        117.000000
# Subcat_946ML                              12.000000
# Subcat_LOYALTYPROG COU(General)          178.000000
# Subcat_Bottle                            935.000000
# total_products                           461.843530
# total_quantity                           473.802263
# recency                                  437.640237
# frequency                                334.880315
# monetary_value                           906.267369
# clusters                                 181.000000
# cluster                                  708.000000
# dtype: float64

# %%
result_list = ["Coupon (General)","Bite Size","HOT TITLES","Non-Menthol Lights KS","Cakes","Non-Menthol Full Flavor KS","FBA Bun(General)","Can","Newspaper (General)","Potato","Menthol Lights KS","Nestle","Menthol Ultra Lights KS","Misc (General)","Appolo","236ML","Tetra Pack","946ML","LOYALTYPROG COU(General)","Bottle"]
#sub_cat_dict = dict(zip(df_pos['Subcat'],df_pos['Prod Name (Chi)'])

for i in result_list:
    print()

# %%
df_transactions.Subcat[0]
# Out:
# 'Newspaper (General)           '
